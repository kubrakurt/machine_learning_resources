# %% [markdown]
# # Hiyerarşik Kümeleme

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df = pd.read_csv("./USArrests.csv", index_col=0)
df.head()
# Out:
#             Murder  Assault  UrbanPop  Rape
# Alabama       13.2      236        58  21.2
# Alaska        10.0      263        48  44.5
# Arizona        8.1      294        80  31.0
# Arkansas       8.8      190        50  19.5
# California     9.0      276        91  40.6

# %%
hc_complete = linkage(df, "complete")
hc_average = linkage(df, "average")

# %% [markdown]
# * **leaf_font_size:** Oluşacak olan x ekseninin boyutudur.

# %%
plt.figure(figsize=(15,10))
dendrogram(hc_complete, leaf_font_size=10)
plt.title("Hiyerarşik Kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar");

# %% [markdown]
# * **truncate_mode:** En son p adet gözlem göstermektedir.
# * **show_contracted:** Kümeler oluşturulduğunda kaçar tane eleman olduğunu göstermektedir.

# %%
plt.figure(figsize=(15,10))
plt.title("Hiyerarşik Kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")

dendrogram(
    hc_complete,
    leaf_font_size=10,
    truncate_mode="lastp",
    show_contracted=True,
    p=4,
);

# %%
plt.figure(figsize=(15,10))
plt.title("Hiyerarşik Kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")

dendrogram(
    hc_complete,
    leaf_font_size=10,
    truncate_mode="lastp",
    show_contracted=True,
    p=10,
);

# %% [markdown]
# * Diğer yönteme bakalım.
# * **leaf_font_size:** Oluşacak olan x ekseninin boyutudur.

# %%
plt.figure(figsize=(15,10))
dendrogram(hc_average, leaf_font_size=10)
plt.title("Hiyerarşik Kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar");

# %%
plt.figure(figsize=(15,10))
plt.title("Hiyerarşik Kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")

dendrogram(
    hc_average,
    leaf_font_size=10,
    truncate_mode="lastp",
    show_contracted=True,
    p=4,
);

# %%
plt.figure(figsize=(15,10))
plt.title("Hiyerarşik Kümeleme Dendogramı")
plt.xlabel("Gözlem Birimleri")
plt.ylabel("Uzaklıklar")

dendrogram(
    hc_average,
    leaf_font_size=10,
    truncate_mode="lastp",
    show_contracted=True,
    p = 10,
);
