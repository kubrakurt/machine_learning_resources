# %% [markdown]
# # Destek Vektör Makinesi (SVM)

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df = pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
y = df["Outcome"]
X = df.drop(["Outcome"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
model = SVC(kernel="linear").fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7445887445887446

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       151
#            1       0.63      0.62      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.72      0.72       231
# weighted avg       0.74      0.74      0.74       231

# %% [markdown]
# * **C:** Ceza Parametresi
# * **Kernel:** Hem doğrusal hem de doğrusal olmayan için denenmesini sağlar.

# %%
params = {
    "C": np.arange(1,10), 
    "kernel": ["linear","rbf"],
}
svm = SVC()
model_cv = GridSearchCV(svm, params, cv=5, n_jobs=-1, verbose=2).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:  1.0min finished

# %%
model_cv.best_score_
# Out:
# 0.7839044652128765

# %%
model_cv.best_params_
# Out:
# {'C': 2, 'kernel': 'linear'}

# %%
model_tuned = SVC(C=2, kernel="linear").fit(X_train, y_train)
y_pred = model_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7445887445887446

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.81      0.81       151
#            1       0.63      0.62      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.72      0.72      0.72       231
# weighted avg       0.74      0.74      0.74       231
